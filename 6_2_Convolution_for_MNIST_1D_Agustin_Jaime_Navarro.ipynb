# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-o4d9v89b
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-o4d9v89b
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
import torch
import torch.nn as nn

# Dimensiones de entrada y salida
D_i = 40  # Longitud de la entrada
D_o = 10  # Número de clases (dígitos 0-9)

# Definición del modelo según los requerimientos
model = nn.Sequential(
    # 1. Capa convolucional (entrada: 1 canal, salida: 15 canales, kernel=3, stride=2)
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 2. Segunda capa convolucional (entrada: 15 canales, salida: 15 canales, kernel=3, stride=2)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 3. Tercera capa convolucional (entrada: 15 canales, salida: 15 canales, kernel=3, stride=2)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 4. Aplanamiento (convierte [batch, 15, 4] en [batch, 60])
    nn.Flatten(),

    # 5. Capa lineal final (entrada=60, salida=10)
    nn.Linear(in_features=60, out_features=D_o)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.804022, training error 72.45, validation loss 1.842249, validation error 76.50
# Epoch     1, training loss 1.514951, training error 61.17, validation loss 1.540423, validation error 64.30
# Epoch     2, training loss 1.358804, training error 56.22, validation loss 1.377811, validation error 59.10
# Epoch     3, training loss 1.309401, training error 53.28, validation loss 1.332175, validation error 56.50
# Epoch     4, training loss 1.203337, training error 47.83, validation loss 1.227618, validation error 50.30
# Epoch     5, training loss 1.115821, training error 43.25, validation loss 1.151768, validation error 48.10
# Epoch     6, training loss 1.035171, training error 41.10, validation loss 1.064324, validation error 45.30
# Epoch     7, training loss 0.916089, training error 36.35, validation loss 0.968979, validation error 39.10
# Epoch     8, training loss 0.856543, training error 33.38, validation loss 0.893397, validation error 36.70
# Epoch     9, training loss 0.790545, training error 30.70, validation loss 0.848950, validation error 35.20
# Epoch    10, training loss 0.678104, training error 26.40, validation loss 0.745073, validation error 29.00
# Epoch    11, training loss 0.616482, training error 23.35, validation loss 0.674411, validation error 25.60
# Epoch    12, training loss 0.540497, training error 20.80, validation loss 0.639058, validation error 21.90
# Epoch    13, training loss 0.500264, training error 18.32, validation loss 0.580383, validation error 22.40
# Epoch    14, training loss 0.429698, training error 16.30, validation loss 0.548754, validation error 19.40
# Epoch    15, training loss 0.435119, training error 16.78, validation loss 0.542033, validation error 19.10
# Epoch    16, training loss 0.357918, training error 12.95, validation loss 0.481488, validation error 16.70
# Epoch    17, training loss 0.310448, training error 11.45, validation loss 0.451104, validation error 15.50
# Epoch    18, training loss 0.330280, training error 12.72, validation loss 0.442534, validation error 14.40
# Epoch    19, training loss 0.359748, training error 13.70, validation loss 0.556675, validation error 18.60
# Epoch    20, training loss 0.219380, training error 7.93, validation loss 0.389099, validation error 11.20
# Epoch    21, training loss 0.182718, training error 6.25, validation loss 0.340238, validation error 11.50
# Epoch    22, training loss 0.182902, training error 6.47, validation loss 0.368700, validation error 12.70
# Epoch    23, training loss 0.160228, training error 5.32, validation loss 0.343742, validation error 10.80
# Epoch    24, training loss 0.166124, training error 6.32, validation loss 0.345824, validation error 12.30
# Epoch    25, training loss 0.152033, training error 5.20, validation loss 0.343960, validation error 11.80
# Epoch    26, training loss 0.148378, training error 5.40, validation loss 0.332532, validation error 11.40
# Epoch    27, training loss 0.147507, training error 5.45, validation loss 0.352139, validation error 12.00
# Epoch    28, training loss 0.134722, training error 4.43, validation loss 0.324940, validation error 10.00
# Epoch    29, training loss 0.145076, training error 5.50, validation loss 0.346515, validation error 9.90
# Epoch    30, training loss 0.126350, training error 4.47, validation loss 0.342924, validation error 10.80
# Epoch    31, training loss 0.123452, training error 4.22, validation loss 0.354436, validation error 11.10
# Epoch    32, training loss 0.144779, training error 5.32, validation loss 0.390283, validation error 11.10
# Epoch    33, training loss 0.117003, training error 4.05, validation loss 0.346726, validation error 10.50
# Epoch    34, training loss 0.106591, training error 3.70, validation loss 0.342868, validation error 10.10
# Epoch    35, training loss 0.116212, training error 3.80, validation loss 0.363952, validation error 11.40
# Epoch    36, training loss 0.090381, training error 2.65, validation loss 0.340647, validation error 10.70
# Epoch    37, training loss 0.119476, training error 4.05, validation loss 0.369810, validation error 10.40
# Epoch    38, training loss 0.104482, training error 3.55, validation loss 0.356714, validation error 10.70
# Epoch    39, training loss 0.125000, training error 4.28, validation loss 0.363676, validation error 10.60
# Epoch    40, training loss 0.073466, training error 2.05, validation loss 0.322453, validation error 9.90
# Epoch    41, training loss 0.070718, training error 1.95, validation loss 0.328211, validation error 9.60
# Epoch    42, training loss 0.077846, training error 2.45, validation loss 0.331908, validation error 10.40
# Epoch    43, training loss 0.068329, training error 1.88, validation loss 0.355090, validation error 9.90
# Epoch    44, training loss 0.068637, training error 2.00, validation loss 0.331240, validation error 9.80
# Epoch    45, training loss 0.072557, training error 2.15, validation loss 0.353587, validation error 10.50
# Epoch    46, training loss 0.064821, training error 1.88, validation loss 0.342620, validation error 9.70
# Epoch    47, training loss 0.059823, training error 1.38, validation loss 0.342073, validation error 9.80
# Epoch    48, training loss 0.060183, training error 1.62, validation loss 0.341295, validation error 10.00
# Epoch    49, training loss 0.060588, training error 1.55, validation loss 0.351884, validation error 10.70
# Epoch    50, training loss 0.059788, training error 1.47, validation loss 0.361646, validation error 9.80
# Epoch    51, training loss 0.075227, training error 2.45, validation loss 0.394591, validation error 10.60
# Epoch    52, training loss 0.067273, training error 2.15, validation loss 0.394955, validation error 10.20
# Epoch    53, training loss 0.055302, training error 1.50, validation loss 0.356153, validation error 9.70
# Epoch    54, training loss 0.055990, training error 1.47, validation loss 0.359424, validation error 10.10
# Epoch    55, training loss 0.053293, training error 1.35, validation loss 0.370347, validation error 10.40
# Epoch    56, training loss 0.054180, training error 1.32, validation loss 0.371175, validation error 10.30
# Epoch    57, training loss 0.072091, training error 2.40, validation loss 0.382813, validation error 10.70
# Epoch    58, training loss 0.056052, training error 1.65, validation loss 0.364693, validation error 10.10
# Epoch    59, training loss 0.049059, training error 1.28, validation loss 0.360157, validation error 10.00
# Epoch    60, training loss 0.048683, training error 1.20, validation loss 0.361763, validation error 9.80
# Epoch    61, training loss 0.045399, training error 1.03, validation loss 0.375641, validation error 10.20
# Epoch    62, training loss 0.046547, training error 1.10, validation loss 0.374938, validation error 10.40
# Epoch    63, training loss 0.044494, training error 1.05, validation loss 0.368403, validation error 10.00
# Epoch    64, training loss 0.044975, training error 1.12, validation loss 0.374574, validation error 9.80
# Epoch    65, training loss 0.044995, training error 1.00, validation loss 0.385710, validation error 10.00
# Epoch    66, training loss 0.044844, training error 1.07, validation loss 0.372901, validation error 9.60
# Epoch    67, training loss 0.043175, training error 1.00, validation loss 0.385700, validation error 9.80
# Epoch    68, training loss 0.042663, training error 0.93, validation loss 0.387170, validation error 10.20
# Epoch    69, training loss 0.042101, training error 0.90, validation loss 0.374373, validation error 10.00
# Epoch    70, training loss 0.042119, training error 0.88, validation loss 0.381501, validation error 10.40
# Epoch    71, training loss 0.041070, training error 0.82, validation loss 0.383202, validation error 10.20
# Epoch    72, training loss 0.040324, training error 0.78, validation loss 0.385784, validation error 9.90
# Epoch    73, training loss 0.042818, training error 1.00, validation loss 0.384151, validation error 10.00
# Epoch    74, training loss 0.039974, training error 0.78, validation loss 0.381819, validation error 9.80
# Epoch    75, training loss 0.041309, training error 0.95, validation loss 0.376663, validation error 9.70
# Epoch    76, training loss 0.041585, training error 1.12, validation loss 0.400779, validation error 10.60
# Epoch    77, training loss 0.039560, training error 0.90, validation loss 0.386430, validation error 10.20
# Epoch    78, training loss 0.038948, training error 0.72, validation loss 0.393545, validation error 10.10
# Epoch    79, training loss 0.037943, training error 0.70, validation loss 0.387748, validation error 10.00
# Epoch    80, training loss 0.038612, training error 0.82, validation loss 0.383358, validation error 9.70
# Epoch    81, training loss 0.037052, training error 0.72, validation loss 0.392979, validation error 9.90
# Epoch    82, training loss 0.037156, training error 0.78, validation loss 0.392085, validation error 10.40
# Epoch    83, training loss 0.036520, training error 0.62, validation loss 0.389506, validation error 10.10
# Epoch    84, training loss 0.036687, training error 0.72, validation loss 0.385552, validation error 9.90
# Epoch    85, training loss 0.036730, training error 0.72, validation loss 0.392909, validation error 9.90
# Epoch    86, training loss 0.036124, training error 0.75, validation loss 0.395176, validation error 10.20
# Epoch    87, training loss 0.036086, training error 0.68, validation loss 0.388692, validation error 10.00
# Epoch    88, training loss 0.035801, training error 0.65, validation loss 0.391459, validation error 9.90
# Epoch    89, training loss 0.035808, training error 0.70, validation loss 0.397402, validation error 10.00
# Epoch    90, training loss 0.035620, training error 0.70, validation loss 0.392087, validation error 10.10
# Epoch    91, training loss 0.035422, training error 0.65, validation loss 0.398060, validation error 10.30
# Epoch    92, training loss 0.035563, training error 0.70, validation loss 0.388360, validation error 10.10
# Epoch    93, training loss 0.036064, training error 0.65, validation loss 0.390668, validation error 9.90
# Epoch    94, training loss 0.034857, training error 0.65, validation loss 0.399192, validation error 10.20
# Epoch    95, training loss 0.035617, training error 0.70, validation loss 0.392288, validation error 10.00
# Epoch    96, training loss 0.035361, training error 0.70, validation loss 0.391536, validation error 9.90
# Epoch    97, training loss 0.036491, training error 0.78, validation loss 0.393655, validation error 9.80
# Epoch    98, training loss 0.035028, training error 0.65, validation loss 0.393183, validation error 10.00
# Epoch    99, training loss 0.034018, training error 0.68, validation loss 0.398612, validation error 9.90
